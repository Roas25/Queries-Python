# %%
# variables
# crear
# nombre_variable = valor
numero = 2
 # USAR

print(numero)
# Out:
# 2

# %%
lista = [1,2,3,4,5,'Hola',True]
lista [-2]
# Out:
#   File "<ipython-input-17-ac21a5e1e8f9>", line 4
#     (yea silla)
#          ^
# SyntaxError: invalid syntax

# %%
print("This will be printed")
frint("This will cause an error")
print("This will NOT be printed")
# Out:
# This will be printed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-aa3f0d14d353> in <module>
#       1 print("This will be printed")
# ----> 2 frint("This will cause an error")
#       3 print("This will NOT be printed")
#
# NameError: name 'frint' is not defined

# %%
if Can_fly == True:
  if is_human == True:
    if has_mask == True
    print('Iron Man')
    if has_mask == False
    print('Captain Marvel')
# Out:
# 60466176
